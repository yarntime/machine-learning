# %%
import numpy as np 
import pandas as pd 
import lightgbm as lgb
import xgboost as xgb
from sklearn.linear_model import BayesianRidge
from sklearn.model_selection import KFold, RepeatedKFold
from scipy import sparse
import warnings
import time
import sys
import os
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import re
from sklearn.metrics import mean_squared_error
from sklearn.metrics import log_loss
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)
pd.set_option('max_colwidth',100)

# %%
train = pd.read_csv("./donejobs.cleaned.csv")

# %%
df_added_features =\
        train['jobName'].str.split(
            ":",
            expand=True)[[1, 2]].rename(columns={1: "jobName_1",
                                                 2: "jobName_2"})
train = pd.concat([train, df_added_features], axis=1)

# %%
del train['jobName']
train.head()
# Out:
#    memReq  numProcessors  avgMem   fromHost  maxMem projectName userGroup  \
# 0  2.7373              1  1.1858  sj-wkchow  1.8959      EDIRND     icd_1
# 1  4.5615              1  1.7877  sj-wkchow  3.2384      EDIRND     icd_1
# 2  2.0156              1  0.7991  sj-wkchow  1.3901      EDIRND     icd_1
# 3  3.1758              1  1.3983  sj-wkchow  2.0619      EDIRND     icd_1
# 4  1.4219              1  0.6040  sj-wkchow  0.9200      EDIRND     icd_1
#
#   userName  cpuTime queue  \
# 0   wkchow  124.374  qosH
# 1   wkchow  222.200  qosH
# 2   wkchow   77.424  qosH
# 3   wkchow  133.506  qosH
# 4   wkchow   97.877  qosH
#
#                                                                                                command  \
# 0  bash /vols/feflowrd_t1b_001/wkchow/sdisk400/qos/rundir/qos_run/TI_ddr_phys_28nm/TI_ddr_phys_28nm...
# 1  bash /vols/feflowrd_t1b_001/wkchow/sdisk400/qos/rundir/qos_run/MMMC_brcm_AVD/MMMC_brcm_AVD_640_1...
# 2  bash /vols/feflowrd_t1b_001/wkchow/sdisk400/qos/rundir/qos_run/GF_trides_mac_20lpm/GF_trides_mac...
# 3  bash /vols/feflowrd_t1b_001/wkchow/sdisk400/qos/rundir/qos_run/FSL_e6500_core_asvaaa_28nm/FSL_e6...
# 4  bash /vols/feflowrd_t1b_001/wkchow/sdisk400/qos/rundir/qos_run/lym0_20nm/lym0_20nm_640_149434878...
#
#   jobName_1                   jobName_2
# 0   humtest            TI_ddr_phys_28nm
# 1   humtest               MMMC_brcm_AVD
# 2   humtest         GF_trides_mac_20lpm
# 3   humtest  FSL_e6500_core_asvaaa_28nm
# 4   humtest                   lym0_20nm

# %%
for f in ['numProcessors','fromHost','projectName','userGroup','userName','queue','command','jobName_1','jobName_2']:
    train[f] = train[f].map(dict(zip(train[f].unique(), range(0, train[f].nunique()))))
train.head()
# Out:
#    memReq  numProcessors  avgMem  fromHost  maxMem  projectName  userGroup  \
# 0  2.7373              0  1.1858         0  1.8959            0        0.0
# 1  4.5615              0  1.7877         0  3.2384            0        0.0
# 2  2.0156              0  0.7991         0  1.3901            0        0.0
# 3  3.1758              0  1.3983         0  2.0619            0        0.0
# 4  1.4219              0  0.6040         0  0.9200            0        0.0
#
#    userName  cpuTime  queue  command  jobName_1  jobName_2
# 0         0  124.374      0        0        0.0        0.0
# 1         0  222.200      0        1        0.0        1.0
# 2         0   77.424      0        2        0.0        2.0
# 3         0  133.506      0        3        0.0        3.0
# 4         0   97.877      0        4        0.0        4.0

# %%
train = train.fillna(-1)
df_train, df_test = train_test_split(train, test_size=0.19999, train_size=0.8)
df_predict = train.drop(df_train.index.union(df_test.index)).reset_index()

# %%
y_train = df_train['maxMem'].values
del df_train['maxMem']
y1_train = df_test['maxMem'].values
del df_test['maxMem']

# %%
features = [f for f in train.columns if f not in ['maxMem']]

X_train = df_train[features].values
X_test = df_test[features].values
# one hot
enc = OneHotEncoder(categories='auto')
for f in features:
    enc.fit(train[f].values.reshape(-1, 1))
    X_train = sparse.hstack((X_train, enc.transform(df_train[f].values.reshape(-1, 1))), 'csr')
    X_test = sparse.hstack((X_test, enc.transform(df_test[f].values.reshape(-1, 1))), 'csr')
print(X_train.shape)
print(X_test.shape)
# Out:
# (320270, 960923)
# (80064, 960923)

# %%
param = {'num_leaves': 120,
         'min_data_in_leaf': 30, 
         'objective':'regression',
         'max_depth': -1,
         'learning_rate': 0.01,
         "min_child_samples": 30,
         "boosting": "gbdt",
         "feature_fraction": 0.9,
         "bagging_freq": 1,
         "bagging_fraction": 0.9,
         "bagging_seed": 11,
         "metric": 'mse',
         "lambda_l1": 0.1,
         "verbosity": -1}

folds = KFold(n_splits=5, shuffle=True, random_state=2018)
oof_lgb = np.zeros(len(df_train))
predictions_lgb = np.zeros(len(df_test))

for fold_, (trn_idx, val_idx) in enumerate(folds.split(X_train, y_train)):
    print("fold n°{}".format(fold_+1))
    trn_data = lgb.Dataset(X_train[trn_idx], y_train[trn_idx])
    val_data = lgb.Dataset(X_train[val_idx], y_train[val_idx])

    clf = lgb.train(param, 
                    trn_data, 
                    num_boost_round=20000, 
                    valid_sets = [trn_data, val_data], 
                    verbose_eval = 200, 
                    early_stopping_rounds = 200)
    oof_lgb[val_idx] = clf.predict(X_train[val_idx], num_iteration=clf.best_iteration)
    
    predictions_lgb += clf.predict(X_test, num_iteration=clf.best_iteration) / folds.n_splits
# Out:
# fold n°1
# Training until validation scores don't improve for 200 rounds.
# [200]	training's l2: 90.5731	valid_1's l2: 108.875
# [400]	training's l2: 59.7617	valid_1's l2: 80.7663
# [600]	training's l2: 48.6514	valid_1's l2: 71.8332
# [800]	training's l2: 42.112	valid_1's l2: 67.7951
# [1000]	training's l2: 37.7108	valid_1's l2: 65.5566
# [1200]	training's l2: 34.2177	valid_1's l2: 63.8095
# [1400]	training's l2: 31.3826	valid_1's l2: 62.7786
# [1600]	training's l2: 29.0969	valid_1's l2: 61.9042
# [1800]	training's l2: 27.1513	valid_1's l2: 61.1767
# [2000]	training's l2: 25.4596	valid_1's l2: 60.4826
# [2200]	training's l2: 23.9366	valid_1's l2: 59.8877
# [2400]	training's l2: 22.6359	valid_1's l2: 59.433
# [2600]	training's l2: 21.4433	valid_1's l2: 59.0944
# [2800]	training's l2: 20.4143	valid_1's l2: 58.7196
# [3000]	training's l2: 19.4609	valid_1's l2: 58.425
# [3200]	training's l2: 18.5676	valid_1's l2: 58.2192
# [3400]	training's l2: 17.7592	valid_1's l2: 57.9803
# [3600]	training's l2: 17.0221	valid_1's l2: 57.8502
# [3800]	training's l2: 16.3384	valid_1's l2: 57.695
# [4000]	training's l2: 15.6874	valid_1's l2: 57.5492
# [4200]	training's l2: 15.1069	valid_1's l2: 57.4494
# [4400]	training's l2: 14.5381	valid_1's l2: 57.3872
# [4600]	training's l2: 14.0163	valid_1's l2: 57.2299
# [4800]	training's l2: 13.5354	valid_1's l2: 57.0919
# [5000]	training's l2: 13.0704	valid_1's l2: 57.0316
# [5200]	training's l2: 12.64	valid_1's l2: 56.9377
# [5400]	training's l2: 12.2387	valid_1's l2: 56.8579
# [5600]	training's l2: 11.8693	valid_1's l2: 56.8222
# [5800]	training's l2: 11.5002	valid_1's l2: 56.783
# [6000]	training's l2: 11.1531	valid_1's l2: 56.7469
# [6200]	training's l2: 10.8351	valid_1's l2: 56.723
# [6400]	training's l2: 10.537	valid_1's l2: 56.67
# [6600]	training's l2: 10.245	valid_1's l2: 56.6274
# [6800]	training's l2: 9.97607	valid_1's l2: 56.6192
# [7000]	training's l2: 9.71477	valid_1's l2: 56.5551
# [7200]	training's l2: 9.47129	valid_1's l2: 56.5384
# Early stopping, best iteration is:
# [7143]	training's l2: 9.54135	valid_1's l2: 56.5254
# fold n°2
# Training until validation scores don't improve for 200 rounds.
# [200]	training's l2: 89.4525	valid_1's l2: 102.394
# [400]	training's l2: 58.6641	valid_1's l2: 80.3116
# [600]	training's l2: 47.7889	valid_1's l2: 74.8059
# [800]	training's l2: 41.8747	valid_1's l2: 72.1197
# [1000]	training's l2: 37.4736	valid_1's l2: 70.3547
# [1200]	training's l2: 34.1616	valid_1's l2: 69.3081
# [1400]	training's l2: 31.4843	valid_1's l2: 68.5504
# [1600]	training's l2: 29.1505	valid_1's l2: 67.9218
# [1800]	training's l2: 27.225	valid_1's l2: 67.4174
# [2000]	training's l2: 25.5282	valid_1's l2: 66.9912
# [2200]	training's l2: 24.0221	valid_1's l2: 66.8067
# [2400]	training's l2: 22.6959	valid_1's l2: 66.6069
# [2600]	training's l2: 21.5433	valid_1's l2: 66.316
# [2800]	training's l2: 20.481	valid_1's l2: 66.1205
# [3000]	training's l2: 19.5438	valid_1's l2: 65.9183
# [3200]	training's l2: 18.6984	valid_1's l2: 65.8065
# [3400]	training's l2: 17.9178	valid_1's l2: 65.7177
# [3600]	training's l2: 17.1951	valid_1's l2: 65.5327
# [3800]	training's l2: 16.5275	valid_1's l2: 65.4726
# [4000]	training's l2: 15.8927	valid_1's l2: 65.4039
# [4200]	training's l2: 15.2942	valid_1's l2: 65.3107
# [4400]	training's l2: 14.7472	valid_1's l2: 65.261
# [4600]	training's l2: 14.2383	valid_1's l2: 65.199
# [4800]	training's l2: 13.7581	valid_1's l2: 65.0935
# [5000]	training's l2: 13.3257	valid_1's l2: 65.0352
# [5200]	training's l2: 12.891	valid_1's l2: 64.9809
# [5400]	training's l2: 12.485	valid_1's l2: 64.9238
# [5600]	training's l2: 12.1167	valid_1's l2: 64.8829
# [5800]	training's l2: 11.756	valid_1's l2: 64.7832
# [6000]	training's l2: 11.4113	valid_1's l2: 64.7367
# [6200]	training's l2: 11.0893	valid_1's l2: 64.7109
# [6400]	training's l2: 10.7924	valid_1's l2: 64.6406
# [6600]	training's l2: 10.5054	valid_1's l2: 64.601
# [6800]	training's l2: 10.222	valid_1's l2: 64.599
# [7000]	training's l2: 9.95763	valid_1's l2: 64.5809
# Early stopping, best iteration is:
# [6897]	training's l2: 10.0946	valid_1's l2: 64.5664
# fold n°3
# Training until validation scores don't improve for 200 rounds.
# [200]	training's l2: 89.222	valid_1's l2: 112.289
# [400]	training's l2: 59.1417	valid_1's l2: 83.1983
# [600]	training's l2: 48.1182	valid_1's l2: 75.0298
# [800]	training's l2: 41.8091	valid_1's l2: 71.5659
# [1000]	training's l2: 37.3573	valid_1's l2: 69.8196
# [1200]	training's l2: 33.9367	valid_1's l2: 68.6632
# [1400]	training's l2: 31.0481	valid_1's l2: 67.6621
# [1600]	training's l2: 28.6446	valid_1's l2: 66.9358
# [1800]	training's l2: 26.6524	valid_1's l2: 66.4894
# [2000]	training's l2: 24.9365	valid_1's l2: 66.0838
# [2200]	training's l2: 23.3904	valid_1's l2: 65.6964
# [2400]	training's l2: 22.025	valid_1's l2: 65.3238
# [2600]	training's l2: 20.8464	valid_1's l2: 65.0039
# [2800]	training's l2: 19.788	valid_1's l2: 64.6971
# [3000]	training's l2: 18.8432	valid_1's l2: 64.5093
# [3200]	training's l2: 17.9541	valid_1's l2: 64.4039
# [3400]	training's l2: 17.1878	valid_1's l2: 64.2286
# [3600]	training's l2: 16.4809	valid_1's l2: 64.044
# [3800]	training's l2: 15.8444	valid_1's l2: 63.8826
# [4000]	training's l2: 15.2002	valid_1's l2: 63.7335
# [4200]	training's l2: 14.6211	valid_1's l2: 63.5762
# [4400]	training's l2: 14.0831	valid_1's l2: 63.4206
# [4600]	training's l2: 13.5923	valid_1's l2: 63.291
# [4800]	training's l2: 13.1313	valid_1's l2: 63.2329
# [5000]	training's l2: 12.6851	valid_1's l2: 63.1208
# [5200]	training's l2: 12.2872	valid_1's l2: 63.0202
# Early stopping, best iteration is:
# [5179]	training's l2: 12.3269	valid_1's l2: 63.0125
# fold n°4
# Training until validation scores don't improve for 200 rounds.
# [200]	training's l2: 89.52	valid_1's l2: 98.7653
# [400]	training's l2: 58.8561	valid_1's l2: 78.2072
# [600]	training's l2: 48.0766	valid_1's l2: 72.5519
# [800]	training's l2: 42.0946	valid_1's l2: 70.0114
# [1000]	training's l2: 37.8227	valid_1's l2: 68.1243
# [1200]	training's l2: 34.5155	valid_1's l2: 66.5292
# [1400]	training's l2: 31.8345	valid_1's l2: 65.2014
# [1600]	training's l2: 29.6199	valid_1's l2: 63.9683
# [1800]	training's l2: 27.772	valid_1's l2: 63.0786
# [2000]	training's l2: 26.0917	valid_1's l2: 62.2791
# [2200]	training's l2: 24.6065	valid_1's l2: 61.6086
# [2400]	training's l2: 23.2798	valid_1's l2: 60.9856
# [2600]	training's l2: 22.1338	valid_1's l2: 60.336
# [2800]	training's l2: 21.0892	valid_1's l2: 59.8868
# [3000]	training's l2: 20.127	valid_1's l2: 59.4493
# [3200]	training's l2: 19.243	valid_1's l2: 59.0813
# [3400]	training's l2: 18.4268	valid_1's l2: 58.7547
# [3600]	training's l2: 17.6926	valid_1's l2: 58.4111
# [3800]	training's l2: 16.9991	valid_1's l2: 58.0193
# [4000]	training's l2: 16.3747	valid_1's l2: 57.8082
# [4200]	training's l2: 15.7837	valid_1's l2: 57.6004
# [4400]	training's l2: 15.2277	valid_1's l2: 57.4405
# [4600]	training's l2: 14.6937	valid_1's l2: 57.1906
# [4800]	training's l2: 14.2068	valid_1's l2: 57.0141
# [5000]	training's l2: 13.7566	valid_1's l2: 56.8149
# [5200]	training's l2: 13.3521	valid_1's l2: 56.6552
# [5400]	training's l2: 12.9387	valid_1's l2: 56.5268
# [5600]	training's l2: 12.562	valid_1's l2: 56.4202
# [5800]	training's l2: 12.1969	valid_1's l2: 56.306
# [6000]	training's l2: 11.8557	valid_1's l2: 56.1983
# [6200]	training's l2: 11.5263	valid_1's l2: 56.107
# [6400]	training's l2: 11.205	valid_1's l2: 55.9723
# [6600]	training's l2: 10.8998	valid_1's l2: 55.9125
# [6800]	training's l2: 10.6229	valid_1's l2: 55.8423
# [7000]	training's l2: 10.3569	valid_1's l2: 55.7707
# [7200]	training's l2: 10.1004	valid_1's l2: 55.6983
# [7400]	training's l2: 9.85831	valid_1's l2: 55.638
# [7600]	training's l2: 9.62963	valid_1's l2: 55.5858
# [7800]	training's l2: 9.40767	valid_1's l2: 55.5109
# [8000]	training's l2: 9.19265	valid_1's l2: 55.4531
# [8200]	training's l2: 8.98716	valid_1's l2: 55.3861
# [8400]	training's l2: 8.79459	valid_1's l2: 55.3351
# [8600]	training's l2: 8.61411	valid_1's l2: 55.3056
# [8800]	training's l2: 8.44133	valid_1's l2: 55.263
# [9000]	training's l2: 8.27024	valid_1's l2: 55.2117
# [9200]	training's l2: 8.10486	valid_1's l2: 55.1626
# [9400]	training's l2: 7.93901	valid_1's l2: 55.0918
# [9600]	training's l2: 7.78064	valid_1's l2: 55.0547
# [9800]	training's l2: 7.6309	valid_1's l2: 55.0072
# [10000]	training's l2: 7.48912	valid_1's l2: 54.9586
# [10200]	training's l2: 7.34783	valid_1's l2: 54.9176
# [10400]	training's l2: 7.21773	valid_1's l2: 54.872
# [10600]	training's l2: 7.09173	valid_1's l2: 54.8538
# [10800]	training's l2: 6.96654	valid_1's l2: 54.8364
# [11000]	training's l2: 6.84834	valid_1's l2: 54.8034
# [11200]	training's l2: 6.73362	valid_1's l2: 54.7862
# [11400]	training's l2: 6.61852	valid_1's l2: 54.7556
# [11600]	training's l2: 6.50529	valid_1's l2: 54.7328
# [11800]	training's l2: 6.39775	valid_1's l2: 54.7218
# [12000]	training's l2: 6.29253	valid_1's l2: 54.6896
# [12200]	training's l2: 6.19423	valid_1's l2: 54.6718
# [12400]	training's l2: 6.09518	valid_1's l2: 54.6558
# [12600]	training's l2: 6.00094	valid_1's l2: 54.6557
# [12800]	training's l2: 5.90921	valid_1's l2: 54.614
# [13000]	training's l2: 5.8209	valid_1's l2: 54.5849
# [13200]	training's l2: 5.73706	valid_1's l2: 54.5593
# [13400]	training's l2: 5.65096	valid_1's l2: 54.5319
# [13600]	training's l2: 5.57076	valid_1's l2: 54.5178
# [13800]	training's l2: 5.4889	valid_1's l2: 54.5091
# [14000]	training's l2: 5.4096	valid_1's l2: 54.496
# [14200]	training's l2: 5.3355	valid_1's l2: 54.492
# [14400]	training's l2: 5.26082	valid_1's l2: 54.4638
# [14600]	training's l2: 5.18844	valid_1's l2: 54.437
# [14800]	training's l2: 5.11456	valid_1's l2: 54.4417
# Early stopping, best iteration is:
# [14621]	training's l2: 5.18067	valid_1's l2: 54.4345
# fold n°5
# Training until validation scores don't improve for 200 rounds.
# [200]	training's l2: 89.5648	valid_1's l2: 96.7218
# [400]	training's l2: 58.9082	valid_1's l2: 74.7573
# [600]	training's l2: 48.1442	valid_1's l2: 68.768
# [800]	training's l2: 42.0888	valid_1's l2: 65.7082
# [1000]	training's l2: 37.7579	valid_1's l2: 63.8935
# [1200]	training's l2: 34.4371	valid_1's l2: 62.6889
# [1400]	training's l2: 31.6996	valid_1's l2: 61.7968
# [1600]	training's l2: 29.4328	valid_1's l2: 61.1935
# [1800]	training's l2: 27.4094	valid_1's l2: 60.6731
# [2000]	training's l2: 25.6703	valid_1's l2: 60.3235
# [2200]	training's l2: 24.161	valid_1's l2: 60.0347
# [2400]	training's l2: 22.8321	valid_1's l2: 59.7725
# [2600]	training's l2: 21.6264	valid_1's l2: 59.5078
# [2800]	training's l2: 20.5225	valid_1's l2: 59.309
# [3000]	training's l2: 19.548	valid_1's l2: 59.0109
# [3200]	training's l2: 18.6729	valid_1's l2: 58.9311
# [3400]	training's l2: 17.8669	valid_1's l2: 58.7499
# [3600]	training's l2: 17.1065	valid_1's l2: 58.6381
# [3800]	training's l2: 16.4151	valid_1's l2: 58.5589
# [4000]	training's l2: 15.8022	valid_1's l2: 58.4912
# [4200]	training's l2: 15.189	valid_1's l2: 58.3391
# [4400]	training's l2: 14.6207	valid_1's l2: 58.2472
# [4600]	training's l2: 14.0888	valid_1's l2: 58.1728
# [4800]	training's l2: 13.5977	valid_1's l2: 58.143
# [5000]	training's l2: 13.1508	valid_1's l2: 58.0392
# [5200]	training's l2: 12.6958	valid_1's l2: 57.9999
# [5400]	training's l2: 12.2998	valid_1's l2: 57.9667
# Early stopping, best iteration is:
# [5309]	training's l2: 12.4789	valid_1's l2: 57.9377

# %%
print("LGB score: {}".format((mean_squared_error(predictions_lgb, y1_train))))
# Out:
# LGB score: 60.3156016983

# %%
print(y1_train.max())
# Out:
# 591.7914

# %%
r = sns.tsplot(y1_train[500:1000], color="red")
b = sns.tsplot(predictions_lgb[500:1000], color="blue")
g = sns.tsplot(abs(y1_train - predictions_lgb)[500:1000], color="green")

# %%
r = sns.tsplot(y1_train[500:600], color="red")
b = sns.tsplot(predictions_lgb[500:600], color="blue")
g = sns.tsplot(abs(y1_train - predictions_lgb)[500:600], color="green")
